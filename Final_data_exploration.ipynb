# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv (r'/Users/Colin/Desktop/Research project/Sigma/Data - Final/Final Data.csv')
df
# Out:
#          gvkey    datadate  fyearq  fqtr indfmt consol popsrc datafmt   tic  \
# 0         1000  31/03/1970    1970   1.0   INDL      C      D     STD  AE.2
# 1         1000  30/06/1970    1970   2.0   INDL      C      D     STD  AE.2
# 2         1000  30/09/1970    1970   3.0   INDL      C      D     STD  AE.2
# 3         1000  31/12/1970    1970   4.0   INDL      C      D     STD  AE.2
# 4         1000  31/03/1971    1971   1.0   INDL      C      D     STD  AE.2
# ...        ...         ...     ...   ...    ...    ...    ...     ...   ...
# 627381  311524  30/09/2013    2013   3.0   INDL      C      D     STD   TAM
# 627382  311524  31/12/2013    2013   4.0   INDL      C      D     STD   TAM
# 627383  311524  31/03/2014    2014   1.0   INDL      C      D     STD   TAM
# 627384  311524  30/06/2014    2014   2.0   INDL      C      D     STD   TAM
# 627385  311524  30/09/2014    2014   3.0   INDL      C      D     STD   TAM
#
# ...

# %%
len(df.columns)
# Out:
# 32
